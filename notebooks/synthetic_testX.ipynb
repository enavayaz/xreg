# %% [markdown]
# # Synthetic Experiments — Ridge Regression on Riemannian Manifolds
#
# Reproduces the synthetic spherical trajectory forecasting experiments reported in
# Table 1 of *Ridge Regression on Riemannian Manifolds for Time-Series Prediction*
# (Nava-Yazdani, Journal of Information Geometry, 2025).
#
# ## Workflow
# 1. Run **Setup** cell
# 2. Either run **Generate** (fresh data, not saved) or **Load** (from `../datasets/`)
# 3. Run **Experiments** cell
# 4. Inspect results in **Table 1** cell
# 5. If satisfied with newly generated data, run **Save** — writes to `../datasets/generated/`
#    (the reference datasets in `../datasets/` are never overwritten)
#
# ## Key constants
# | Variable | Value | Description |
# |---|---|---|
# | `DEGREE` | 5 | Degree of Bézier polynomial; `n_cp = DEGREE+1` control points |
# | `N_SUBJ` | 30 | Total trajectories per template |
# | `N_TRAIN/N_VAL/N_TEST` | 20/5/5 | Train / validation / test split |
# | `N_POINTS` | 35 | Time points per trajectory |
# | `NOISE_STD` | 0.05 | Individual (within-trajectory) noise std |
# | `BETWEEN_STD` | 2.0 | Shared between-trajectory perturbation std; induces correlation ρ=0.80 |
# | `DIAG_LOAD` | 0.0 | Diagonal loading added to covariance (0.0 = none; try 1e-6 if singular) |
# | `TEMPLATES` | Geo, Poly, Else | Mean trajectory shapes: geodesic, cubic Bézier, sinusoidal |
# | `LAM_STAR` | [20, 11, 3] | Fixed optimal λ per template; set to `None` to run grid search |
# | `AVG` | `None` | Post-process ensemble: `None` = pure ridge (α=1); `AVGEnsemble(0.5)` = adjusted |
# | `scale_mu` | 1e-3 | Ridge regularization scale factor (see code comments) |
# | `SEED` | 42 | Random seed for reproducibility |

# %%
# %load_ext autoreload
# %autoreload 2
#%env JAX_PLATFORM_NAME=gpu
#%env XLA_PYTHON_CLIENT_PREALLOCATE=false
import numpy as np
import numpy.linalg as lg
from morphomatics.manifold import Sphere, PowerManifold
from morphomatics.stats import ExponentialBarycenter
from timeseries.stats import sph_correlated_trjs
from timeseries.main import pred
from timeseries.model import Reg, RidgeReg, AVGEnsemble
from helpers.util_pred import cov_mat, fit_poly_dc

SEED      = 42
np.random.seed(SEED)

M  = Sphere()
Ex = ExponentialBarycenter()

DEGREE      = 5
N_SUBJ      = 30
N_TRAIN     = 20
N_VAL       = 5
N_TEST      = 5
N_POINTS    = 35
NOISE_STD   = 0.05
BETWEEN_STD = 2.0
LON_MAX     = 0.75 * np.pi
LAT_MAX     = np.pi / 20
DIAG_LOAD   = 0.0   # 1e-6
TEMPLATES   = ['Geo', 'Poly', 'Else']
LAM_STAR    = [20.0, 11.0, 3.0]  # set to None to run grid search
LAG = True
AVG         = None  # None = pure ridge (alpha=1); AVGEnsemble(0.5) = post-process averaging
PRED_ARGS = {'n_learn': DEGREE + 1, 'n_pred': 1, 'iterative': True}
print(f'seed={SEED}  degree={DEGREE}  split={N_TRAIN}/{N_VAL}/{N_TEST}')
# Out:
# seed=42  degree=5  split=20/5/5

# %% [markdown]
# ## Helper functions

# %%
LOAD_PATH = '../datasets'            # reference datasets used in paper
SAVE_PATH = '../datasets/generated'  # newly generated data saved here

def save_path(template):
    import os; os.makedirs(SAVE_PATH, exist_ok=True)
    return f'{SAVE_PATH}/sph{template}.npz'

def save_data(Y, B, template):
    path = save_path(template)
    np.savez(path,
             Y=np.array(Y, dtype=object),
             B=np.array(B))
    print(f'  Saved -> {path}')

def load_data(template):
    path = f'{LOAD_PATH}/sph{template}.npz'
    data = np.load(path, allow_pickle=True)
    Y = list(data['Y'])
    B = list(data['B'])
    print(f'  Loaded <- {path}')
    return Y, B

def coarse_to_fine_grid_search(Y_val, model_fn, coarse_grid, n_refine=3, factor=4.0):
    """Two-stage coarse-to-fine grid search over lambda (ridge only)."""
    all_results = {}

    # Stage 1: coarse pass
    print(f'  Coarse pass: [{", ".join(f"{l:.1e}" for l in coarse_grid)}]')
    for lam in coarse_grid:
        _, m = pred(Y_val, model_fn(lam), **PRED_ARGS, prnt=False)
        all_results[lam] = m['mae']
        print(f'    lambda={lam:.1e}  val MAE={m["mae"]:.4f}')

    lam_coarse_best = min(all_results, key=all_results.get)

    # Stage 2: fine pass around best coarse lambda
    log_center = np.log10(lam_coarse_best)
    log_range  = np.log10(factor)
    fine_grid  = np.logspace(log_center - log_range, log_center + log_range, n_refine).tolist()
    fine_grid  = [l for l in fine_grid
                  if not any(abs(l - ev) / ev < 0.01 for ev in all_results)]

    if fine_grid:
        print(f'  Fine pass around lambda={lam_coarse_best:.1e}: [{", ".join(f"{l:.2e}" for l in fine_grid)}]')
        for lam in fine_grid:
            _, m = pred(Y_val, model_fn(lam), **PRED_ARGS, prnt=False)
            all_results[lam] = m['mae']
            print(f'    lambda={lam:.2e}  val MAE={m["mae"]:.4f}')

    return min(all_results, key=all_results.get), all_results

def run_experiment(template, Y_train, Y_val, Y_test, B_train):
    print(f"\n{'='*60}")
    print(f'Experiment: {template}')
    print(f"{'='*60}")

    n_cp = np.shape(B_train[0])[0]
    dim  = 3
    P    = PowerManifold(M, n_cp)
    PRED_ARGS['n_learn'] = n_cp
    # covariance — diagonal loading for numerical safety before cov_intrinsic
    mean_b  = Ex.compute(P, B_train, max_iter=30)
    cov_b   = cov_mat(P.metric.log, B_train, mean_b) + DIAG_LOAD * np.eye(n_cp * dim)
    eigvals = np.sort(lg.eigvalsh(cov_b))[::-1]
    print(f'  Eigenvalues: {np.round(eigvals, 6)}')

    # scale: noise^2 * M.dim / mean_dominant_eig
    # makes ridge_const = mu * scale, so mu=1 ~ theoretically balanced
    # dominant = above DIAG_LOAD (structural zeros lifted to DIAG_LOAD, still dominant below)
    # dominant eigenvalues: above numerical noise floor regardless of DIAG_LOAD
    dominant_eigs = eigvals[eigvals > 1e-6]
    scale_mu = 1e-3#NOISE_STD**2 * M.dim / np.mean(dominant_eigs)
    print(f'  scale_mu={scale_mu:.3e}  ({len(dominant_eigs)} dominant eigs, mean_eig={np.mean(dominant_eigs):.3e})')

    # model factory: ridge_const = mu * scale_mu passed to RidgeRegression
    def model_fn(lam):
        if lam == 0:
            return Reg(M, lag=LAG, degree=DEGREE)
        return RidgeReg(M, mean_b, cov_b, lam * scale_mu, lag=LAG, degree=DEGREE, ensemble=AVG)

    # OLS on val and test
    _, m_ols_val = pred(Y_val,  model_fn(0), **PRED_ARGS, prnt=False)
    _, m_ols     = pred(Y_test, model_fn(0), **PRED_ARGS, prnt=False)
    print(f'  OLS  MAE: {m_ols["mae"]:.4f} +/- {m_ols["std"]:.4f}')
    if LAM_STAR is None:
        # grid search — centered around mu=1e-3..1 based on theoretical analysis
        # mu_balanced ~ mean_eig^2 * n_cp / (M.dim * dist_to_mean^2) ~ 1e-3
        COARSE_GRID = [0.2, 5, 10, 20]
        lam_star, val_results = coarse_to_fine_grid_search(
            Y_val, model_fn, COARSE_GRID, n_refine=3, factor=4.0
        )
        # fall back to OLS if ridge does not improve on val
        if m_ols_val['mae'] <= val_results[lam_star]:
            lam_star = 0
        print(f'  lambda* = {lam_star:.2e}  (ridge_const = {lam_star * scale_mu:.2e})')
    else:
        idx = TEMPLATES.index(template)
        lam_star = LAM_STAR[idx]
    # ridge on test
    _, m_ridge  = pred(Y_test, model_fn(lam_star), **PRED_ARGS, prnt=False)
    improvement = 100 * (m_ols['mae'] - m_ridge['mae']) / m_ols['mae']
    print(f'  Ridge MAE: {m_ridge["mae"]:.4f} +/- {m_ridge["std"]:.4f}  (improvement: {improvement:.1f}%)')
    return {
        'ols_mean':    m_ols['mae'],
        'ols_std':     m_ols['std'],
        'ridge_mean':  m_ridge['mae'],
        'ridge_std':   m_ridge['std'],
        'lam_star':    lam_star,
        'scale_mu':    scale_mu,
        'improvement': improvement,
    }

# %% [markdown]
# ## Generate Data
#
# Generates fresh data — **does not save to disk**.
# Inspect results first, then run the **Save** cell if satisfied.

# %%
all_data = {}
for template in TEMPLATES:
    print(f'Generating {N_SUBJ} trajectories (template={template}) ...')
    Y, _ = sph_correlated_trjs(
        LON_MAX, LAT_MAX,
        n_trj=N_SUBJ, n_points=N_POINTS,
        noise_std=NOISE_STD, between_std=BETWEEN_STD, mean_curve=template
    )
    print(f'  Fitting Bezier polynomials ...')
    B, _ = fit_poly_dc(M, Y, deg=DEGREE)
    all_data[template] = {'Y': Y, 'B': B}
    print(f'  Done.')
print("Data ready to run experiment. To save data run 'Save' cell.")
# Out:
# Generating 30 trajectories (template=Geo) ...
#   Fitting Bezier polynomials ...
#   Done.
# Generating 30 trajectories (template=Poly) ...
#   Fitting Bezier polynomials ...
#   Done.
# Generating 30 trajectories (template=Else) ...
#   Fitting Bezier polynomials ...
#   Done.
# Data ready to run experiment. To save data run 'Save' cell.

# %% [markdown]
# ## Load Data
#
# Run this cell **instead of Generate** to reload previously saved data.

# %%
all_data = {}
for template in TEMPLATES:
    Y, B = load_data(template)
    all_data[template] = {'Y': Y, 'B': B}

# Infer data parameters from loaded arrays
_Y0 = all_data[TEMPLATES[0]]['Y']
_B0 = all_data[TEMPLATES[0]]['B']
N_SUBJ   = len(_Y0)
N_POINTS = len(_Y0[0])
DEGREE   = len(_B0[0]) - 1
print(f'Loaded: N_SUBJ={N_SUBJ}, N_POINTS={N_POINTS}, DEGREE={DEGREE}')
print(f'Using split: {N_TRAIN}/{N_VAL}/{N_TEST}')
# Out:
#   Loaded <- ../datasets/sphGeo.npz
#   Loaded <- ../datasets/sphPoly.npz
#   Loaded <- ../datasets/sphElse.npz
# Loaded: N_SUBJ=30, N_POINTS=35, DEGREE=5
# Using split: 20/5/5

# %% [markdown]
# ## Run Experiments

# %%
results = {}
for template in TEMPLATES:
    d = all_data[template]
    Y, B = d['Y'], d['B']
    results[template] = run_experiment(
        template,
        Y[:N_TRAIN],
        Y[N_TRAIN:N_TRAIN + N_VAL],
        Y[N_TRAIN + N_VAL:],
        B[:N_TRAIN]
    )
# Out:
# ============================================================
# Experiment: Geo
# ============================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       3 d = all_data[template]
#       4 Y, B = d['Y'], d['B']
# ----> 5 results[template] = run_experiment(
#       6     template,
#       7     Y[:N_TRAIN],
#       8     Y[N_TRAIN:N_TRAIN + N_VAL],
#       9     Y[N_TRAIN + N_VAL:],
#      10     B[:N_TRAIN]
#      11 )
#
# Cell In[2], line 62, in run_experiment(template, Y_train, Y_val, Y_test, B_train)
#      60 PRED_ARGS['n_learn'] = n_cp
#      61 # covariance — diagonal loading for numerical safety before cov_intrinsic
# ---> 62 mean_b  = Ex.compute(P, B_train, max_iter=30)
#      63 cov_b   = cov_mat(P.metric.log, B_train, mean_b) + DIAG_LOAD * np.eye(n_cp * dim)
#      64 eigvals = np.sort(lg.eigvalsh(cov_b))[::-1]
#
#     [... skipping hidden 13 frame]
#
# File ~\anaconda3\envs\mycondaenv\Lib\site-packages\morphomatics\stats\exponential_barycenter.py:59, in ExponentialBarycenter.compute(mfd, data, x, max_iter)
#      56     c = jnp.array([g_norm > 1e-6, i < max_iter])
#      57     return jnp.all(c)
# ---> 59 x, g_norm, i = jax.lax.while_loop(cond, body, (x, jnp.array(1.), jnp.array(0)))
#      60 # print(g_norm, i)
#      62 return x
#
#     [... skipping hidden 10 frame]
#
# File ~\anaconda3\envs\mycondaenv\Lib\site-packages\morphomatics\stats\exponential_barycenter.py:49, in ExponentialBarycenter.compute.<locals>.body(args)
#      47 def body(args):
#      48     x, g_norm, i = args
# ---> 49     g = jnp.sum(jax.vmap(mfd.connec.log, (None, 0))(x, data), axis=0) / len(data)
#      50     g_norm = jax.numpy.linalg.norm(g) if mfd.metric is None else mfd.metric.norm(x, g)
#      51     x = mfd.connec.exp(x, g)
#
#     [... skipping hidden 7 frame]
#
# File ~\anaconda3\envs\mycondaenv\Lib\site-packages\morphomatics\manifold\power_manifold.py:249, in PowerManifold.ProductMetric.log(self, p, q)
#     242 def log(self, p: jnp.array, q: jnp.array) -> jnp.array:
#     243     """Riemannian logarithm
#     244
#     245     :param p: element of M^k
#     246     :param q: element of M^k
#     247     :return: vector at p with exp(p, v) = q
#     248     """
# --> 249     return jax.vmap(self.atom_mfd.connec.log)(p, q)
#
#     [... skipping hidden 2 frame]
#
# File ~\anaconda3\envs\mycondaenv\Lib\site-packages\jax\_src\api.py:1131, in _mapped_axis_size(fn, tree, vals, dims, name)
#    1129   else:
#    1130     msg.append(f"  * some axes ({ct} of them) had size {sz}, e.g. axis {ax} of {ex};\n")
# -> 1131 raise ValueError(''.join(msg)[:-2])
#
# ValueError: vmap got inconsistent sizes for array axes to be mapped:
#   * most axes (20 of them) had size 3, e.g. axis 0 of argument q[0] of type float64[3];
#   * one axis had size 6: axis 0 of argument p of type float64[6,3]

# %% [markdown]
# ## Table 1

# %%
print(f"{'='*70}")
print('Table 1 -- MAE (radians), synthetic spherical trajectory forecasting')
print(f"{'='*70}")
print(f"{'Experiment':<12} {'OLS':<26} {'Ridge (proposed)':<26} {'Impr.':>6}  lambda*")
print('-'*70)
for name, r in results.items():
    print(f"{name:<12} "
          f"{r['ols_mean']:.4f} +/- {r['ols_std']:.4f}      "
          f"{r['ridge_mean']:.4f} +/- {r['ridge_std']:.4f}    "
          f"{r['improvement']:+.1f}%   {r['lam_star']}")
print('-'*70)
avg_imp = np.mean([r['improvement'] for r in results.values()])
print(f"{'Average improvement:':<40} {avg_imp:+.1f}%")
print(f"{'='*70}")
print(f'seed={SEED}  |  degree={DEGREE}  |  split={N_TRAIN}/{N_VAL}/{N_TEST}')
print(f'covariance: sample + {DIAG_LOAD}*I (diagonal loading)')

# %% [markdown]
# ## Save Data
#
# Run this cell **only when satisfied** with the results.

# %%
for template in TEMPLATES:
    d = all_data[template]
    save_data(d['Y'], d['B'], template)
print('All data saved.')
